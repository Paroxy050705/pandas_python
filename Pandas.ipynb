# %% [markdown]
# # Series

# %%
import pandas as pd
x=[3,4,5,6,7,8,9]
var=pd.Series(x)
print(var)
print(type(var))
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# 5    8
# 6    9
# dtype: int64
# <class 'pandas.core.series.Series'>
